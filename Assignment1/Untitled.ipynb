# %%
import pandas as pd
import numpy as np
import numpy.random as rd
from sklearn.model_selection import train_test_split

df = pd.read_csv('heart.csv', index_col=0)
df = pd.DataFrame(df)
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 1     63    1       typical     145   233    1        2    150      0
# 2     67    1  asymptomatic     160   286    0        2    108      1
# 3     67    1  asymptomatic     120   229    0        2    129      1
# 4     37    1    nonanginal     130   250    0        0    187      0
# 5     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 299   45    1       typical     110   264    0        0    132      0
# 300   68    1  asymptomatic     144   193    1        0    141      0
# 301   57    1  asymptomatic     130   131    0        0    115      1
# 302   57    0    nontypical     130   236    0        2    174      0
# 303   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 1        2.3      3  0.0       fixed   No
# 2        1.5      2  3.0      normal  Yes
# 3        2.6      2  2.0  reversable  Yes
# 4        3.5      3  0.0      normal   No
# 5        1.4      1  0.0      normal   No
# ..       ...    ...  ...         ...  ...
# 299      1.2      2  0.0  reversable  Yes
# 300      3.4      2  2.0  reversable  Yes
# 301      1.2      2  1.0  reversable  Yes
# 302      0.0      2  1.0      normal  Yes
# 303      0.0      1  NaN      normal   No
#
# [303 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# dtype: int64

# %%
df.dtypes
# Out:
# Age            int64
# Sex            int64
# ChestPain     object
# RestBP         int64
# Chol           int64
# Fbs            int64
# RestECG        int64
# MaxHR          int64
# ExAng          int64
# Oldpeak      float64
# Slope          int64
# Ca           float64
# Thal          object
# AHD           object
# dtype: object

# %%
for i in df:
    ans = (df[i] == 0).sum()
    print(ans)
# Out:
# 0
# 97
# 0
# 0
# 0
# 258
# 151
# 0
# 204
# 99
# 0
# 176
# 0
# 0

# %%
df['Age'].mean()
# Out:
# 54.43894389438944

# %%
xtrain = df.sample(frac=0.75)
xtrain
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 11    57    1  asymptomatic     140   192    0        0    148      0
# 209   55    1    nontypical     130   262    0        0    155      0
# 38    57    1  asymptomatic     150   276    0        2    112      1
# 253   64    1  asymptomatic     128   263    0        0    105      1
# 75    44    1  asymptomatic     110   197    0        2    177      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 226   34    0    nontypical     118   210    0        0    192      0
# 174   62    0  asymptomatic     140   394    0        2    157      0
# 283   55    0  asymptomatic     128   205    0        1    130      1
# 245   60    0    nonanginal     120   178    1        0     96      0
# 131   54    1    nonanginal     120   258    0        2    147      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 11       0.4      2  0.0       fixed   No
# 209      0.0      1  0.0      normal   No
# 38       0.6      2  1.0       fixed  Yes
# 253      0.2      2  1.0  reversable   No
# 75       0.0      1  1.0      normal  Yes
# ..       ...    ...  ...         ...  ...
# 226      0.7      1  0.0      normal   No
# 174      1.2      2  0.0      normal   No
# 283      2.0      2  1.0  reversable  Yes
# 245      0.0      1  0.0      normal   No
# 131      0.4      2  0.0  reversable   No
#
# [227 rows x 14 columns]

# %%
xtest = df.drop(xtrain.index)
xtest
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 12    56    0    nontypical     140   294    0        2    153      0
# 15    52    1    nonanginal     172   199    1        0    162      0
# 21    64    1       typical     110   211    0        2    144      1
# 22    58    0       typical     150   283    1        2    162      0
# 29    43    1  asymptomatic     150   247    0        0    171      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 292   55    0    nontypical     132   342    0        0    166      0
# 295   63    0  asymptomatic     124   197    0        0    136      1
# 296   41    1    nontypical     120   157    0        0    182      0
# 300   68    1  asymptomatic     144   193    1        0    141      0
# 301   57    1  asymptomatic     130   131    0        0    115      1
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 12       1.3      2  0.0      normal   No
# 15       0.5      1  0.0  reversable   No
# 21       1.8      2  0.0      normal   No
# 22       1.0      1  0.0      normal   No
# 29       1.5      1  0.0      normal   No
# ..       ...    ...  ...         ...  ...
# 292      1.2      1  0.0      normal   No
# 295      0.0      2  0.0      normal  Yes
# 296      0.0      1  0.0      normal   No
# 300      3.4      2  2.0  reversable  Yes
# 301      1.2      2  1.0  reversable  Yes
#
# [76 rows x 14 columns]

# %%
x = df.iloc[:, :-1]
y = df.iloc[:,-1]

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25)
